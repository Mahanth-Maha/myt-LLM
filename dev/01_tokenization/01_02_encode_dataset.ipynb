# %% [markdown]
# # Encode Train, Val, Test splits

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tqdm import tqdm


import torch
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F

# %%
import sentencepiece as spm

tokenizer = spm.SentencePieceProcessor()
tokenizer.load("wikitext_spm.model")
# Out:
# True

# %%
from datasets import load_dataset

# ds = load_dataset("Salesforce/wikitext", "wikitext-103-raw-v1")
ds = load_dataset("Salesforce/wikitext", "wikitext-2-raw-v1")
ds
# Out:
# DatasetDict({
#     test: Dataset({
#         features: ['text'],
#         num_rows: 4358
#     })
#     train: Dataset({
#         features: ['text'],
#         num_rows: 36718
#     })
#     validation: Dataset({
#         features: ['text'],
#         num_rows: 3760
#     })
# })

# %%
def get_text(typ = ds['train']):
    all_text = ''
    for row in typ:
        if row['text']:
            all_text += row['text']
    return all_text 

def get_encoded_text(typ = ds['train']):
    encs = []
    for row in typ:
        if row['text']:
            encs.extend(tokenizer.encode(row['text']))
    return encs

# %%
# Xtr = torch.tensor(tokenizer.encode(get_text(ds['train'])), dtype=torch.long)
# Xtr.shape
Xtr = torch.tensor(get_encoded_text(ds['train']), dtype=torch.long)
Xtr.shape
# Out:
# torch.Size([3197288])

# %%
# Xval = torch.tensor(tokenizer.encode(get_text(ds['validation'])), dtype=torch.long)
# Xval.shape
Xval = torch.tensor(get_encoded_text(ds['validation']), dtype=torch.long)
Xval.shape
# Out:
# torch.Size([336540])

# %%
# Xte = torch.tensor(tokenizer.encode(get_text(ds['test'])), dtype=torch.long)
# Xte.shape
Xte = torch.tensor(get_encoded_text(ds['test']), dtype=torch.long)
Xte.shape
# Out:
# torch.Size([383891])

# %%
print(f'{Xtr.shape = }, {Xval.shape = }, {Xte.shape = }')
# Out:
# Xtr.shape = torch.Size([3197288]), Xval.shape = torch.Size([336540]), Xte.shape = torch.Size([383891])

# %%
import os 
os.makedirs('saved_tensors',exist_ok=True)

torch.save(Xtr, 'saved_tensors/Xtr_mini.pt')
torch.save(Xval, 'saved_tensors/Xval_mini.pt')
torch.save(Xte, 'saved_tensors/Xte_mini.pt')
